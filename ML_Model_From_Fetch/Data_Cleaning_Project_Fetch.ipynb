# %%
# importing the needed packets.
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    precision_score,
    recall_score,
    make_scorer,
    classification_report,
    ConfusionMatrixDisplay
)
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

from sklearn import tree
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier

import xgboost as xgb

# %%
# Loading in the data with , as a delimiter to properly get the data frame loaded.
the_weather_data = pd.read_csv("../the_weather_data.csv", delimiter=',')

pd.set_option('display.max_columns', 20)

# %%
the_weather_data
# Out:
#      clouds    datetime  dewpt  dhi  dni  ghi  max_dhi  max_dni  max_ghi  \
# 0        75  2023-11-08    4.7   16  142   39       64      575      192
# 1        88  2023-11-09    5.2   16  139   38       64      569      188
# 2        91  2023-11-10    6.8   16  136   37       63      564      183
# 3        70  2023-11-11    5.6   15  133   35       62      558      178
# 4        84  2023-11-12    2.9   15  129   34       62      552      174
# ..      ...         ...    ...  ...  ...  ...      ...      ...      ...
# 295       9  2024-08-29   13.0   45  378  216      104      832      629
# 296      33  2024-08-30   15.4   45  375  213      104      831      624
# 297       1  2024-08-31    9.9   45  372  210      103      829      618
# 298      45  2024-09-01    8.1   44  369  207      103      827      613
# 299      39  2024-09-02   11.6   44  366  204      103      826      607
#
#      max_temp  ...  solar_rad  t_dhi  t_dni  t_ghi  t_solar_rad  temp  \
# ...

# %%
the_weather_data.drop(columns=['dhi','dni','ghi','max_dhi','max_dni','max_ghi','max_temp','wind_dir','t_solar_rad','datetime','dewpt'], inplace=True)

# %%
the_weather_data.drop(columns=['max_uv','max_wind_dir','snow_depth','max_wind_spd_ts','min_temp_ts'], inplace=True)

# %%
the_weather_data
the_weather_data.drop(columns=['snow','revision_status'], inplace=True)

# %%
the_weather_data
# Out:
#      clouds  max_temp_ts  max_wind_spd  min_temp revision_status  snow  \
# 0        75   1699452000           3.2       3.0           final   0.0
# 1        88   1699560000           5.2       3.0           final   0.0
# 2        91   1699614000           3.2       5.0           final   0.0
# 3        70   1699704000           2.5       5.0           final   0.0
# 4        84   1699743600           4.4       2.0           final   0.0
# ..      ...          ...           ...       ...             ...   ...
# 295       9   1724936400           8.1      12.0         interim   0.0
# 296      33   1725004800           5.4      13.0         interim   0.0
# 297       1   1725109200           6.8      12.0         interim   0.0
# 298      45   1725195600           4.1      10.0         interim   0.0
# 299      39   1725289200           4.2      12.0         interim   0.0
#
#      solar_rad  temp  wind_gust_spd  wind_spd
# 0            4   5.4            6.8       2.0
# ...

# %%
the_weather_data.to_csv('The_cleaned_weather_data.csv', index=False)
